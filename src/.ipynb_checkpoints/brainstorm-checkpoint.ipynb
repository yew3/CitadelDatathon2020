# %%
import numpy as np
import pandas as pd
import os
import sys
from pathlib import Path
from datetime import datetime, timezone, timedelta
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# CONSTANTS
path = os.getcwd()   
DATA_DIR = os.path.abspath(os.path.join(path, os.pardir, "data"))
MOVIE_LENS_DIR = os.path.abspath(os.path.join(path,  os.pardir, "data", "movie_lense"))
NETFLIX_DIR = os.path.abspath(os.path.join(path,  os.pardir, "data", "netflix"))
MOVIE_DIR = os.path.abspath(os.path.join(path,  os.pardir, "data", "ml-1m"))

# %%
industry_df = pd.read_csv(os.path.join(DATA_DIR, "movie_industry.csv"), encoding='latin-1')
oscar_df = pd.read_csv(os.path.join(DATA_DIR, "the_oscar_award.csv"))

# %%
users_df = pd.read_csv(os.path.join(MOVIE_DIR, "users.dat"), delimiter= "::")
# Out:
# /Users/sophia/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
len(users_df["48067"].unique())
# Out:
#          1  F  1.1  10  48067
# 0        2  M   56  16  70072
# 1        3  M   25  15  55117
# 2        4  M   45   7  02460
# 3        5  M   25  20  55455
# 4        6  F   50   9  55117
# 5        7  M   35   1  06810
# 6        8  M   25  12  11413
# 7        9  M   25  17  61614
# 8       10  F   35   1  95370
# 9       11  F   25   1  04093
# 10      12  M   25  12  32793
# 11      13  M   45   1  93304
# 12      14  M   35   0  60126
# 13      15  M   25   7  22903
# 14      16  F   35   0  20670
# 15      17  M   50   1  95350
# 16      18  F   18   3  95825
# 17      19  M    1  10  48073
# 18      20  M   25  14  55113
# 19      21  M   18  16  99353
# 20      22  M   18  15  53706
# 21      23  M   35   0  90049
# 22      24  F   25   7  10023
# 23      25  M   18   4  01609
# 24      26  M   25   7  23112
# 25      27  M   25  11  19130
# 26      28  F   25   1  14607
# 27      29  M   35   7  33407
# 28      30  F   35   7  19143
# 29      31  M   56   7  06840
# ...    ... ..  ...  ..    ...
# 6009  6011  M   35  15  80538
# 6010  6012  M   35  15  02871
# 6011  6013  F   25  20  32301
# 6012  6014  M   45   1  80634
# 6013  6015  F   25   9  80013
# 6014  6016  M   45   1  37209
# 6015  6017  F   35   7  21117
# 6016  6018  M   35   1  48906
# 6017  6019  M   25   0  10024
# 6018  6020  M   50  16  10023
# 6019  6021  M   25  12  08876
# 6020  6022  M   25  17  57006
# 6021  6023  M   25   0  43213
# 6022  6024  M   25  12  53705
# 6023  6025  F   25   1  32607
# 6024  6026  M   35   6  11210
# 6025  6027  M   18   4  20742
# 6026  6028  M   18   4  94133
# 6027  6029  F   25   1  23185
# 6028  6030  M   25  17  32618
# 6029  6031  F   18   0  45123
# 6030  6032  M   45   7  55108
# 6031  6033  M   50  13  78232
# 6032  6034  M   25  14  94117
# 6033  6035  F   25   1  78734
# 6034  6036  F   25  15  32603
# 6035  6037  F   45   1  76006
# 6036  6038  F   56   1  14706
# 6037  6039  F   45   0  01060
# 6038  6040  M   25   6  11106
#
# [6039 rows x 5 columns]

# %%
# January 1, 1970, UTC
t = datetime(1970, 1, 1, tzinfo=timezone.utc)

score_df = pd.read_csv(os.path.join(MOVIE_LENS_DIR, "genome-scores.csv"))
genome_tag_df = pd.read_csv(os.path.join(MOVIE_LENS_DIR, "genome-tags.csv"))
ratings_df = pd.read_csv(os.path.join(MOVIE_LENS_DIR, "ratings.csv"))
movies_df = pd.read_csv(os.path.join(MOVIE_LENS_DIR, "movies.csv"))
tags_df = pd.read_csv(os.path.join(MOVIE_LENS_DIR, "tags.csv"))
links_df = pd.read_csv(os.path.join(MOVIE_LENS_DIR, "links.csv"))
print(t)
# Out:
# 1970-01-01 00:00:00+00:00

# %%
industry_df = industry_df.loc[industry_df['budget'] != 0]

# %%
industry_df["net_revenue"] = industry_df.gross-industry_df.budget

# %%
foreign_films = industry_df.loc[industry_df['country'] != "USA"]

# %%
sns.scatterplot(data = foreign_films, x= "released", y="net_revenue")

# %%
# calculates actual date from timestamp and origin time (january 1st 1970 UTC)
tags_df["date"] = tags_df.timestamp.apply(lambda x: timedelta(seconds=x) + t)

# %%
tags = pd.merge(tags_df, ratings_df, on=['userId', 'movieId']).groupby("tag")["rating"].mean().sort_values()

# %%
genome_tag_df["date"] = tags_df.timestamp.apply(lambda x: timedelta(seconds=x) + t)

# %%
tag_score_df = pd.merge(score_df, genome_tag_df, on=['tagId'])
